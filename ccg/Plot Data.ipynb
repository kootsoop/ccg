# %%
import numpy as np

#infile = open('sin1.wvd.out', 'r')
#infile = open('fm.wvd', 'r')
infile = open('fm.R.out', 'r')
numbers = [float(line) for line in infile.readlines()]
infile.close()
print(len(numbers))

matrix = np.reshape(numbers, [128,128])
# Out:
# 16384

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig = plt.figure(figsize=(20, 20))
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(0, 128, 1)
Y = np.arange(0, 128, 1)
X, Y = np.meshgrid(X, Y)

#urf = ax.plot_surface(X, Y, matrix, cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)
#
#ax.view_init(elev=45., azim=0)


#plt.figure(1)
#fig.set_figheight(100)
#fig.set_figwidth(100)
fig.set_size_inches(100, 100)
plt.contourf(X,Y,matrix, 50, cmap=plt.get_cmap('hot'))
ax.view_init(elev=90., azim=0)
plt.axis('off')
# Out:
# (-6.3500000000000005, 133.35, -6.3500000000000005, 133.35)
